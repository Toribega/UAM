# %% [markdown]
# <a href="https://colab.research.google.com/github/Toribega/UAM/blob/main/%ED%9A%8C%EA%B7%80%EB%B6%84%EC%84%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import statsmodels.api as sm

# CSV 파일 불러오기
df = pd.read_csv('/content/설문조사결과 Raw Data-1 (1).csv', encoding='utf-8')

# 변수명 수정
df.rename(columns={'1.1	나는 여행을 통해 일상에서 잠시 휴식을 취하고 싶은 욕구를 자주 느낀다': '관광동기1',
                   '1.2	고급 숙박 시설, 고급 식사, 특별한 경험의 매력이 여행 선택에 중요한 부분이다': '관광동기2',
                   '1.3	여행을 하면서 새롭고 다양한 경험을 찾는 것에 관심이 있다': '관광동기3',
                   '1.4	변화에 대한 열망과 활력이 여행 결정에 영향을 미친다': '관광동기4',
                   '1.5	여행 중에 자연과 연결되는 것이 얼마나 중요합니까?': '관광동기5',
                   '3.1	관광지 간 이동은 여행의 중요한 부분이다': '관광지_이동수단1',
                   '3.2	관광지 간 이동수단의 편리성은 여행 만족도에 영향이 크다': '관광지_이동수단2',
                   '1.1	UAM이 나에게 유용할 것이다': '유용성',
                   '2.1	나는 흥미와 즐거움을 느끼기 위해 UAM을 사용할 것이다': '사용의도1',
                   '2.2	나는 호기심이 많아 UAM을 사용해보고 싶다': '사용의도2',
                   '4.3	나는 UAM이 무엇인지 알고 있다': '사용의도3',
                   '4.4	나는 UAM에 대해서 관심이 많다': '사용의도4',
                   '5.1	나는 혁신적인 새로운 기술에 대해서 관심이 많다': '수용태도',
                   '1. UAM 이용 금액이 1km X 3000원이라고 할때 UAM을 탑승할 의향이 있으십니까?': '이용금액3000',
                   '2. UAM 이용 금액이 1km X 2000원이라고 할때 UAM을 탑승할 의향이 있으십니까?': '이용금액2000',
                   '3. UAM 이용 금액이 1km X 1300원이라고 할때 UAM을 탑승할 의향이 있으십니까?': '이용금액1300',
                   '2. 귀하의 연령은 어떻게 되십니까?': '연령',
                   '7.1	운송 옵션을 선택할 때 환경 지속 가능성은 중요하다': '환경친화성'}, inplace=True)

# 설문문항을 합쳐서 하나의 종속 변수 생성
df['사용의도'] = df['사용의도1'] + df['사용의도2'] + df['사용의도3'] + df['사용의도4']
df['관광동기'] = df['관광동기1'] + df['관광동기2'] + df['관광동기3'] + df['관광동기4'] + df['관광동기5']
df['관광지_이동수단_편리성&중요성'] = df['관광지_이동수단1'] + df['관광지_이동수단2']

# %% [markdown]
# 종속 변수에 '사용의도'를 넣었을 때

# %%
# 종속 변수
dependent_variable1 = '사용의도'


# 독립 변수에 상수 항 추가
X = sm.add_constant(df[['관광동기', '관광지_이동수단_편리성&중요성', '이용금액3000', '이용금액2000', '이용금액1300', '환경친화성']])

# 종속 변수
y = df[dependent_variable1]

# 선형 회귀 모델 생성
model = sm.OLS(y, X)

# 모델 피팅
results1 = model.fit()

# 회귀분석 결과 출력
print(results1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   사용의도   R-squared:                       0.351
# Model:                            OLS   Adj. R-squared:                  0.347
# Method:                 Least Squares   F-statistic:                     89.51
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):           9.20e-90
# Time:                        12:16:14   Log-Likelihood:                -2453.4
# No. Observations:                1000   AIC:                             4921.
# Df Residuals:                     993   BIC:                             4955.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                4.0338      0.916      4.403      0.000       2.236       5.832
# ...

# %%
# 회귀분석 결과를 표 형식으로 정리
summary_df = pd.DataFrame(results1.summary().tables[1].data[1:], columns=results1.summary().tables[1].data[0])

# 결과 표 출력
summary_df
# Out:
#                            coef    std err          t   P>|t|     [0.025  \
# 0             const      4.0338      0.916      4.403   0.000      2.236
# 1              관광동기      0.4374      0.033     13.075   0.000      0.372
# 2  관광지_이동수단_편리성&중요성      0.0016      0.083      0.020   0.984     -0.161
# 3          이용금액3000     -0.1663      0.149     -1.115   0.265     -0.459
# 4          이용금액2000     -0.4529      0.127     -3.564   0.000     -0.702
# 5          이용금액1300     -0.8908      0.121     -7.381   0.000     -1.128
# 6             환경친화성      0.8104      0.120      6.754   0.000      0.575
#
#       0.975]
# 0      5.832
# 1      0.503
# 2      0.165
# 3      0.126
# 4     -0.204
# 5     -0.654
# 6      1.046

# %% [markdown]
# 종속 변수에 '유용성'를 넣었을 때

# %%
# 종속 변수
dependent_variable2 = '유용성'


# 독립 변수에 상수 항 추가
X = sm.add_constant(df[['관광동기', '관광지_이동수단_편리성&중요성', '이용금액3000', '이용금액2000', '이용금액1300', '환경친화성']])

# 종속 변수
y = df[dependent_variable2]

# 선형 회귀 모델 생성
model = sm.OLS(y, X)

# 모델 피팅
results2 = model.fit()

# 회귀분석 결과 출력
print(results2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    유용성   R-squared:                       0.213
# Model:                            OLS   Adj. R-squared:                  0.208
# Method:                 Least Squares   F-statistic:                     44.73
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):           1.49e-48
# Time:                        12:16:14   Log-Likelihood:                -1284.6
# No. Observations:                1000   AIC:                             2583.
# Df Residuals:                     993   BIC:                             2618.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                0.8562      0.285      3.008      0.003       0.298       1.415
# ...

# %%
# 회귀분석 결과를 표 형식으로 정리
summary_df = pd.DataFrame(results2.summary().tables[1].data[1:], columns=results2.summary().tables[1].data[0])

# 결과 표 출력
summary_df
# Out:
#                            coef    std err          t   P>|t|     [0.025  \
# 0             const      0.8562      0.285      3.008   0.003      0.298
# 1              관광동기      0.0829      0.010      7.972   0.000      0.062
# 2  관광지_이동수단_편리성&중요성      0.0625      0.026      2.420   0.016      0.012
# 3          이용금액3000      0.0252      0.046      0.543   0.587     -0.066
# 4          이용금액2000     -0.1257      0.039     -3.183   0.002     -0.203
# 5          이용금액1300     -0.2043      0.038     -5.449   0.000     -0.278
# 6             환경친화성      0.1777      0.037      4.767   0.000      0.105
#
#       0.975]
# 0      1.415
# 1      0.103
# 2      0.113
# 3      0.116
# 4     -0.048
# 5     -0.131
# 6      0.251

# %% [markdown]
# 종속 변수에 '사용태도'를 넣었을 때

# %%
# 종속 변수
dependent_variable3 = '수용태도'


# 독립 변수에 상수 항 추가
X = sm.add_constant(df[['관광동기', '관광지_이동수단_편리성&중요성', '이용금액3000', '이용금액2000', '이용금액1300', '환경친화성']])

# 종속 변수
y = df[dependent_variable3]

# 선형 회귀 모델 생성
model = sm.OLS(y, X)

# 모델 피팅
results3 = model.fit()

# 회귀분석 결과 출력
print(results3.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   수용태도   R-squared:                       0.256
# Model:                            OLS   Adj. R-squared:                  0.251
# Method:                 Least Squares   F-statistic:                     56.93
# Date:                Sun, 18 Feb 2024   Prob (F-statistic):           1.47e-60
# Time:                        12:16:14   Log-Likelihood:                -1249.5
# No. Observations:                1000   AIC:                             2513.
# Df Residuals:                     993   BIC:                             2547.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const                1.0689      0.275      3.889      0.000       0.530       1.608
# ...

# %%
# 회귀분석 결과를 표 형식으로 정리
summary_df = pd.DataFrame(results3.summary().tables[1].data[1:], columns=results3.summary().tables[1].data[0])

# 결과 표 출력
summary_df
# Out:
#                            coef    std err          t   P>|t|     [0.025  \
# 0             const      1.0689      0.275      3.889   0.000      0.530
# 1              관광동기      0.1117      0.010     11.129   0.000      0.092
# 2  관광지_이동수단_편리성&중요성      0.0187      0.025      0.751   0.453     -0.030
# 3          이용금액3000     -0.0727      0.045     -1.624   0.105     -0.160
# 4          이용금액2000     -0.1042      0.038     -2.733   0.006     -0.179
# 5          이용금액1300     -0.1712      0.036     -4.727   0.000     -0.242
# 6             환경친화성      0.1697      0.036      4.714   0.000      0.099
#
#       0.975]
# 0      1.608
# 1      0.131
# 2      0.068
# 3      0.015
# 4     -0.029
# 5     -0.100
# 6      0.240
